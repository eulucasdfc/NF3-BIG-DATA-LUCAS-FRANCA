# %% [markdown]
# <a href="https://colab.research.google.com/github/eulucasdfc/NF3-BIG-DATA-LUCAS-FRANCA/blob/main/Nota_Final_3_Ex2_BigData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Aluno: Lucas de França Carvalho
#Matricula: 202102286115

# %%
#2. Seja o dataset chamado cursos-prouni.csv que se encontra no endereço Cursos e notas de corte do
#PROUNI 2018 - Datasets - Brasil.IO. Baixe o arquivo, armazene no seu github** e obtenha os dados a
#partir desse endereço do github e realize as seguintes análises (2,5 pontos):
import pandas as pd

prouni = pd.read_csv('https://raw.githubusercontent.com/eulucasdfc/NF3-BIG-DATA-LUCAS-FRANCA/main/cursos-prouni.csv', sep = ',')
prouni
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral      9999.99                  15.0
# 1       Bacharelado            Noturno      9836.40                   1.0
# 2       Bacharelado           Integral      9715.61                   2.0
# 3       Bacharelado            Noturno      9689.34                   3.0
# 4       Bacharelado           Integral      9674.34                   4.0
# ...             ...                ...          ...                   ...
# 41442  Licenciatura  Curso a Distância       149.00                   1.0
# 41443   Tecnológico  Curso a Distância       144.00                   1.0
# 41444   Tecnológico         Vespertino       139.00                   1.0
# 41445   Bacharelado  Curso a Distância       139.00                   1.0
# 41446   Tecnológico  Curso a Distância       139.00                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
#a. Efetuar a limpeza das colunas de notas: onde tiver NaN (Not a Number), substituir por 0,0.
import pandas as pd
prouni_fillna = prouni.fillna(0)

prouni_fillna
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral      9999.99                  15.0
# 1       Bacharelado            Noturno      9836.40                   1.0
# 2       Bacharelado           Integral      9715.61                   2.0
# 3       Bacharelado            Noturno      9689.34                   3.0
# 4       Bacharelado           Integral      9674.34                   4.0
# ...             ...                ...          ...                   ...
# 41442  Licenciatura  Curso a Distância       149.00                   1.0
# 41443   Tecnológico  Curso a Distância       144.00                   1.0
# 41444   Tecnológico         Vespertino       139.00                   1.0
# 41445   Bacharelado  Curso a Distância       139.00                   1.0
# 41446   Tecnológico  Curso a Distância       139.00                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
#b. Agrupe os dados pelo grau (Bacharelado, Licenciatura, etc).
import pandas as pd
groupby_grau = prouni.groupby('grau')

groupby_grau.std()
# Out:
# <ipython-input-3-6a12bd27a4f7>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groupby_grau.std()
#               mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# grau
# Bacharelado    765.639255              2.489715              3.467606
# Licenciatura   237.634550              2.237158              2.828028
# Tecnológico    245.188479              1.402747              1.954153
#
#               bolsa_parcial_cotas  bolsa_parcial_ampla      curso_id  \
# grau
# Bacharelado              1.922274            21.461921  5.616329e+13
# Licenciatura             3.836732            14.191033  6.811028e+13
# Tecnológico              1.125798            13.731446  6.139310e+13
#
#                   campus_id  nota_integral_ampla  nota_integral_cotas  \
# grau
# ...

# %%
#c. Agrupe os dados pelos cursos de Matemática, Medicina e Pedagogia.
import pandas as pd
cursos = pd.read_csv('https://raw.githubusercontent.com/eulucasdfc/NF3-BIG-DATA-LUCAS-FRANCA/main/cursos-prouni.csv', sep = ',', index_col = 'curso_busca')

groupby_cursos = cursos.loc[["Matemática", "Medicina", "Pedagogia"]].groupby('curso_busca')
groupby_cursos.std()
# Out:
# <ipython-input-4-8acdd458e5ed>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groupby_cursos.std()
#              mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# curso_busca
# Matemática    197.351107               0.88121              2.203236
# Medicina     1085.360331               3.33079              3.596733
# Pedagogia     185.358843               3.17412              3.134415
#
#              bolsa_parcial_cotas  bolsa_parcial_ampla      curso_id  \
# curso_busca
# Matemática              0.666383             9.635705  7.524799e+13
# Medicina                2.378261             2.566855  3.731167e+13
# Pedagogia               6.630283            18.046781  3.694682e+13
#
#                  campus_id  nota_integral_ampla  nota_integral_cotas  \
# curso_busca
# ...

# %%
#d. Agrupe os dados por Estado e obtenha a média de notas de corte por Estado.
import pandas as pd

groupby_estado = prouni.groupby('uf_busca')['nota_integral_ampla'].mean()
print("Média das notas por Estado\n", groupby_estado)
# Out:
# Média das notas por Estado
#  uf_busca
# AC    592.320255
# AL    598.094599
# AM    580.413199
# AP    583.807126
# BA    588.942140
# CE    630.480894
# DF    586.136432
# ES    605.744498
# GO    573.088620
# MA    608.524744
# MG    592.559059
# MS    554.571593
# MT    540.597958
# PA    588.270892
# PB    604.280388
# PE    598.066841
# PI    605.636839
# PR    562.998106
# RJ    605.651400
# RN    607.561447
# RO    577.266182
# RR    558.540842
# RS    567.415515
# SC    542.574038
# SE    600.468716
# SP    562.488484
# TO    579.278425
# Name: nota_integral_ampla, dtype: float64

# %%
#e. Agrupe os dados pelos cursos Tecnológicos.
import pandas as pd
grau = pd.read_csv('https://raw.githubusercontent.com/eulucasdfc/NF3-BIG-DATA-LUCAS-FRANCA/main/cursos-prouni.csv', sep = ',', index_col = 'grau')

groupby_tecno = grau.loc[["Tecnológico"]].groupby('curso_busca')
groupby_tecno.std()
# Out:
# <ipython-input-6-48fe8ec3f5a5>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.std is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   groupby_tecno.std()
#                                        mensalidade  bolsa_integral_cotas  \
# curso_busca
# Agroindústria                                  NaN                   NaN
# Agronegócio                             165.746758              1.182750
# Agropecuária                                   NaN                   NaN
# Alimentos                               188.695700              0.577350
# Análise e Desenvolvimento de Sistemas   231.497734              1.705314
# ...                                            ...                   ...
# Tecnólogo em Metalurgia                   0.000000              0.000000
# Turismo Receptivo                        46.307349              0.816497
# ...

# %%
#f. Elimine a coluna “cidade_filtro” do dataframe.
import pandas as pd
prouni.drop(columns=['cidade_filtro'])
# Out:
#                grau              turno  mensalidade  bolsa_integral_cotas  \
# 0       Bacharelado           Integral      9999.99                  15.0
# 1       Bacharelado            Noturno      9836.40                   1.0
# 2       Bacharelado           Integral      9715.61                   2.0
# 3       Bacharelado            Noturno      9689.34                   3.0
# 4       Bacharelado           Integral      9674.34                   4.0
# ...             ...                ...          ...                   ...
# 41442  Licenciatura  Curso a Distância       149.00                   1.0
# 41443   Tecnológico  Curso a Distância       144.00                   1.0
# 41444   Tecnológico         Vespertino       139.00                   1.0
# 41445   Bacharelado  Curso a Distância       139.00                   1.0
# 41446   Tecnológico  Curso a Distância       139.00                   3.0
#
#        bolsa_integral_ampla  bolsa_parcial_cotas  bolsa_parcial_ampla  \
# ...

# %%
#g. Apresente a média das mensalidades dos cursos de Medicina.
import pandas as pd
medicina = cursos.loc[["Medicina"]]

print("Média: ", medicina['mensalidade'].mean())
# Out:
# Média:  7168.341532258064

# %%
#h. Média das notas de corte dos cursos de tempo integral.
import pandas as pd

tempo_nota = prouni[(prouni['turno'] == 'Integral') & (prouni['nota_integral_ampla'])]

print("Média: ", tempo_nota['nota_integral_ampla'].mean())
# Out:
# Média:  663.1000342465754

# %%
#i. Estatística Descritiva das Notas Integral Ampla dos cursos de Bacharelado.
import pandas as pd

bacharel_nota = prouni[(prouni['grau'] == 'Bacharelado') & (prouni['nota_integral_ampla'])]

notas = bacharel_nota['nota_integral_ampla'].describe()

print("Estatistica Descritiva\n", notas)
# Out:
# Estatistica Descritiva
#  count    15911.000000
# mean       603.084487
# std         49.863617
# min        450.000000
# 25%        575.440000
# 50%        605.480000
# 75%        633.900000
# max        781.200000
# Name: nota_integral_ampla, dtype: float64

# %%
#j. Gráfico comparativo entre o grau dos cursos (Bacharelado, Licenciatura, Tecnologia, etc) pelas Notas Integral de Cotas.

groupby_grau_nota = prouni.groupby('grau')['nota_integral_ampla'].std()
groupby_grau_nota

groupby_grau_nota.plot.bar(x='App', y='nota_integral_ampla')
# Out:
# <Axes: xlabel='grau'>
